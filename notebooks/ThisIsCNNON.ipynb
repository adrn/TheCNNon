# %%
# Third-party
import astropy.coordinates as coord
import astropy.units as u
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
#plt.style.use('apw-notebook')
# %matplotlib inline
import h5py

#from __future__ import print_function

from keras.models import Sequential
from keras.layers import Convolution1D, Convolution2D, GlobalMaxPooling1D, MaxPooling1D
from keras.layers.core import Dense, Activation, Dropout, Flatten
# Out:
# Using TensorFlow backend.

# %%
# test data
filename_data = "testdata.h5"
dir_data = "data001/"

# sim data
filename_data = "apogee-spectra.h5"
dir_data = "data002/"

# %%
dir_base = "/Users/nord/Dropbox/TheCNNon/"
dir_data_full = dir_base + dir_data
file_data = dir_data_full + filename_data

# %%
with h5py.File('/home/bsesar/projects/TheCNNon/notebooks/data002/apogee-spectra.h5', 'r') as f:
    X = f['X'][:]#.astype(np.float32)
    y = f['y'][:]#.astype(np.float32)

y = y[:,0:1]
y = y - min(y)
y = y / max(y)
print min(y), max(y)

X[np.isnan(X)] = 0.
# Out:
# [ 0.] [ 1.]

# %%
idx = np.random.choice(len(X), size=len(X), replace=False)
X = X[idx]
y = y[idx]

# %%
n_train = 2048
n_valid = 1024
nb_epoch = 30
#n_test = X.shape[0] - n_train - n_valid
n_test = 2048
print("Train, Valid, Test", n_train, n_valid, n_test)
# Out:
# ('Train, Valid, Test', 2048, 1024, 2048)

# %%
X_train = X[:n_train]
y_train = y[:n_train,:1]

X_valid = X[n_train:n_train+n_valid]
y_valid = y[n_train:n_train+n_valid,:1]

X_test = X[n_train+n_valid:]
y_test = y[n_train+n_valid:,:1]
n_objects, n_pixels = X_train.shape
n_objects, n_pixels
# Out:
# (2048, 8575)

# %%
plt.hist(y_train, alpha=0.5, normed=True, label='train');
plt.hist(y_valid, alpha=0.5, normed=True, label='valid');
plt.hist(y_test, alpha=0.5, normed=True, label='test');
plt.legend()

# %%
model = Sequential()

model.add(Convolution1D(nb_filter=128, filter_length=32, input_dim=1))
model.add(Activation('relu'))
model.add(MaxPooling1D(pool_length=32))


model.add(Convolution1D(nb_filter=128, filter_length=16, input_dim=1))
model.add(Activation('relu'))
model.add(MaxPooling1D(pool_length=16))


model.add(Convolution1D(nb_filter=128, filter_length=8, input_dim=1))
model.add(Activation('relu'))
model.add(MaxPooling1D(pool_length=8))

#model.add(Convolution1D(nb_filter=128, filter_length=2, input_dim=1))
#model.add(Activation('relu'))
#model.add(MaxPooling1D(pool_length=2))

# We add a vanilla hidden layer:
# model.add(Dense(128))
# model.add(Dropout(0.5))

model.add(Dense(96))
model.add(Dropout(0.50))
#model.add(Activation('sigmoid'))

model.add(GlobalMaxPooling1D())

# We project onto a single unit output layer, and squash it with a sigmoid:
model.add(Dense(1))

optimizer = 'adadelta'
#optimizer="rmsprop"
model.compile(loss="mse", optimizer=optimizer)
model.summary()
# Out:
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ====================================================================================================
# convolution1d_10 (Convolution1D) (None, None, 128)     4224        convolution1d_input_4[0][0]
# ____________________________________________________________________________________________________
# activation_10 (Activation)       (None, None, 128)     0           convolution1d_10[0][0]
# ____________________________________________________________________________________________________
# maxpooling1d_10 (MaxPooling1D)   (None, None, 128)     0           activation_10[0][0]
# ____________________________________________________________________________________________________
# convolution1d_11 (Convolution1D) (None, None, 128)     262272      maxpooling1d_10[0][0]
# ____________________________________________________________________________________________________
# activation_11 (Activation)       (None, None, 128)     0           convolution1d_11[0][0]
# ____________________________________________________________________________________________________
# maxpooling1d_11 (MaxPooling1D)   (None, None, 128)     0           activation_11[0][0]
# ____________________________________________________________________________________________________
# convolution1d_12 (Convolution1D) (None, None, 128)     131200      maxpooling1d_11[0][0]
# ____________________________________________________________________________________________________
# activation_12 (Activation)       (None, None, 128)     0           convolution1d_12[0][0]
# ____________________________________________________________________________________________________
# maxpooling1d_12 (MaxPooling1D)   (None, None, 128)     0           activation_12[0][0]
# ____________________________________________________________________________________________________
# dense_7 (Dense)                  (None, None, 96)      12384       maxpooling1d_12[0][0]
# ____________________________________________________________________________________________________
# dropout_4 (Dropout)              (None, None, 96)      0           dense_7[0][0]
# ____________________________________________________________________________________________________
# globalmaxpooling1d_4 (GlobalMaxP (None, 96)            0           dropout_4[0][0]
# ____________________________________________________________________________________________________
# dense_8 (Dense)                  (None, 1)             97          globalmaxpooling1d_4[0][0]
# ====================================================================================================
# Total params: 410,177
# Trainable params: 410,177
# Non-trainable params: 0
# ____________________________________________________________________________________________________

# %%
history = model.fit(X_train.reshape(len(X_train), n_pixels, 1), y_train, nb_epoch=nb_epoch, batch_size=32,
          validation_data=(X_valid.reshape(len(X_valid), n_pixels, 1), y_valid), verbose=True)
# Out:
# Train on 2048 samples, validate on 1024 samples
# Epoch 1/30
# 2048/2048 [==============================] - 27s - loss: 0.0426 - val_loss: 0.0304
# Epoch 2/30
# 2048/2048 [==============================] - 27s - loss: 0.0291 - val_loss: 0.0260
# Epoch 3/30
# 2048/2048 [==============================] - 27s - loss: 0.0318 - val_loss: 0.0296
# Epoch 4/30
# 2048/2048 [==============================] - 27s - loss: 0.0277 - val_loss: 0.0364
# Epoch 5/30
# 2048/2048 [==============================] - 27s - loss: 0.0265 - val_loss: 0.0215
# Epoch 6/30
# 2048/2048 [==============================] - 27s - loss: 0.0249 - val_loss: 0.0264
# Epoch 7/30
# 2048/2048 [==============================] - 27s - loss: 0.0233 - val_loss: 0.0183
# Epoch 8/30
# 2048/2048 [==============================] - 27s - loss: 0.0189 - val_loss: 0.0173
# Epoch 9/30
# 2048/2048 [==============================] - 27s - loss: 0.0149 - val_loss: 0.0087
# Epoch 10/30
# 2048/2048 [==============================] - 27s - loss: 0.0111 - val_loss: 0.0053
# Epoch 11/30
# 2048/2048 [==============================] - 28s - loss: 0.0080 - val_loss: 0.0056
# Epoch 12/30
# 2048/2048 [==============================] - 27s - loss: 0.0078 - val_loss: 0.0078
# Epoch 13/30
# 2048/2048 [==============================] - 27s - loss: 0.0066 - val_loss: 0.0039
# Epoch 14/30
# 2048/2048 [==============================] - 27s - loss: 0.0060 - val_loss: 0.0030
# Epoch 15/30
# 2048/2048 [==============================] - 27s - loss: 0.0051 - val_loss: 0.0032
# Epoch 16/30
# 2048/2048 [==============================] - 28s - loss: 0.0051 - val_loss: 0.0065
# Epoch 17/30
# 2048/2048 [==============================] - 27s - loss: 0.0046 - val_loss: 0.0024
# Epoch 18/30
# 2048/2048 [==============================] - 27s - loss: 0.0049 - val_loss: 0.0015
# Epoch 19/30
# 2048/2048 [==============================] - 27s - loss: 0.0052 - val_loss: 0.0014
# Epoch 20/30
# 2048/2048 [==============================] - 27s - loss: 0.0043 - val_loss: 0.0109
# Epoch 21/30
# 2048/2048 [==============================] - 27s - loss: 0.0045 - val_loss: 0.0017
# Epoch 22/30
# 2048/2048 [==============================] - 27s - loss: 0.0037 - val_loss: 0.0027
# Epoch 23/30
# 2048/2048 [==============================] - 27s - loss: 0.0038 - val_loss: 0.0011
# Epoch 24/30
# 2048/2048 [==============================] - 27s - loss: 0.0033 - val_loss: 0.0014
# Epoch 25/30
# 2048/2048 [==============================] - 28s - loss: 0.0034 - val_loss: 0.0063
# Epoch 26/30
# 2048/2048 [==============================] - 28s - loss: 0.0040 - val_loss: 0.0018
# Epoch 27/30
# 2048/2048 [==============================] - 27s - loss: 0.0033 - val_loss: 0.0011
# Epoch 28/30
# 2048/2048 [==============================] - 27s - loss: 0.0034 - val_loss: 0.0010
# Epoch 29/30
# 2048/2048 [==============================] - 27s - loss: 0.0035 - val_loss: 0.0010
# Epoch 30/30
# 2048/2048 [==============================] - 27s - loss: 0.0031 - val_loss: 0.0010

# %%
# History
hist = history.history
loss = hist['loss']
val_loss = hist["val_loss"]
epochs = np.arange(nb_epoch)
figsize=(5,3)
fig, axis1 = plt.subplots(figsize=figsize)
plot1_loss = axis1.plot(epochs, loss, 'b', label='loss')
plot1_val_loss = axis1.plot(epochs, val_loss, 'r', label="val loss")
plots = plot1_loss + plot1_val_loss
labs = [l.get_label() for l in plots]
axis1.set_xlabel('Epoch')
axis1.set_ylabel('Loss')
plt.title("Loss History")
plt.tight_layout()
axis1.legend(loc='upper right')

# %%
y_pred = model.predict(X_test.reshape(len(X_test), n_pixels, 1), verbose=True)
# Out:
# 1024/1024 [==============================] - 3s

# %%
bins =  np.linspace(0.0, 1, 100)
plt.hist(y_test,color='red', alpha=0.5);# bins = bins);
plt.hist(y_pred,color='blue', alpha=0.5);# bins=bins);

# %%
plt.scatter(y_test,y_pred)
xline = yline  = np.linspace(0.,1.1, 32)
plt.plot(xline,yline,color='red')

# %%
data  =(y_test-y_pred)/y_test#), bins='auto');
#plt.hist(np.log10(np.abs((y_test-y_pred)/y_test)), bins='auto');
plt.hist(data, bins=np.logspace(-3, 1.0, 50))
plt.gca().set_xscale("log")

# %%
f_model = "./model.json"
f_weights = "./weights.h5"
model.save_weights(f_weights)
open(f_model, 'w').write(model.to_json())
